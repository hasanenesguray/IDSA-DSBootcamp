# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def mean_std_filling(column_name):    
    mean = column_name.mean()
    std = column_name.std()
    is_null = column_name.isna().sum()
    print('Mean:', round(mean,3), 'Std:', round(std,3), 'Null:', is_null)

    # Elimizdeki dizinin aritmetik ortalama ve standart sapma değerlerini kullanarak rastgele float veriler üretme
    rand_float = np.random.uniform(mean - std, mean + std, size = is_null)
    print('Numbers:', rand_float[:10])

    # Oluşturduğumuz sayılarla boş değerlerimizi doldurma
    column_name[pd.isnull(column_name)] = rand_float
    column_name = column_name.astype(float)

# %%
df = pd.read_csv('/Users/hasanenesguray/Desktop/Bootcamp/Projects/2. Project/zingat_final.csv')
df.head()
# Out:
#    Unnamed: 0                                      listing_names  \
# 0           0  Kadiköy Moda Sarraf Ali Sokak'ta Eşyalı Satılı...
# 1           1  KADIKÖY BAHARİYE CADDESİNE 50 METRE MESAFEDE 7...
# 2           2          ANA CADDE ÜZERİNDE KİRACILI 100 M2 DÜKKAN
# 3           3  KADIKÖY ÇARŞISININ HAREKETLİ YERİNDE 300 M2 DÜ...
# 4           4  KADIKÖY MODA DA OTOPARKLI YENİ BİNADA FERAH 13...
#
#    listing_prices  location  netm2  bedroom_number  building_floor_number  \
# 0         2750000  Caferağa   55.0            21.0                    6.0
# 1         4750000  Caferağa   60.0             1.0                    4.0
# 2         4750000  Caferağa   85.0             2.0                    5.0
# 3        15000000  Caferağa  255.0             3.0                    4.0
# 4         9750000  Caferağa  100.0            31.0                    4.0
#
#           floor        heating_system    age situation    seller  \
# 0             6  Kalorifer (Doğalgaz)  36-40       Boş  Danışman
# 1     Zemin Kat                 Klima  16-20  Kiracılı  Danışman
# 2     Zemin Kat        Merkezi Sistem  11-15  Kiracılı  Danışman
# 3     Zemin Kat      Kombi (Doğalgaz)  16-20  Kiracılı  Danışman
# 4  Yüksek Giriş      Kombi (Doğalgaz)   6-10      Mülk       NaN
#
#   title_dead_status credit  rent_income
# 0               NaN  Hayır      30000.0
# 1     Kat Mülkiyeti   Evet          NaN
# 2     Kat Mülkiyeti   Evet          NaN
# 3     Kat Mülkiyeti   Evet          NaN
# 4               NaN   Evet          0.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'listing_names', 'listing_prices', 'location', 'netm2',
#        'bedroom_number', 'building_floor_number', 'floor', 'heating_system',
#        'age', 'situation', 'seller', 'title_dead_status', 'credit',
#        'rent_income'],
#       dtype='object')

# %%
df.replace(np.nan,None,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1712 non-null   object
#  5   bedroom_number         1679 non-null   object
#  6   building_floor_number  1713 non-null   object
#  7   floor                  1647 non-null   object
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
# dtypes: int64(2), object(13)
# memory usage: 216.2+ KB

# %%
#Checking listing_prices column

df.listing_prices.unique()
# Out:
# array([  2750000,   4750000,  15000000,   9750000,  11950000,   2475000,
#          6400000,   3250000,   3050000,  55000000,   4000000,   4250000,
#         14000000,   3150000,   4300000,   4800000,  40000000,  28000000,
#         35000000,   3500000,  30000000,   4500000,   6750000,  10000000,
#          8500000,  18500000,   5000000,   5500000,  12500000,  25000000,
#          7500000,  90000000,   3750000,   7000000,   2950000,  27500000,
#         17500000,  22500000,   9500000,    650000,  51275000, 150000000,
#          8400000,   5800000,   1750000,   7200000,  45000000,   6500000,
#          6450000,    660000,   6800000,  23500000,   6000000,   7250000,
#          5200000,   3600000,   1500000,    600000,   1800000,   3000000,
#          4150000, 115000000,  14500000,  23000000,   5750000,   3100000,
#         11750000,    990000,   3850000,  18750000,   1250000,   8000000,
#         20000000,  12000000,   3800000,  89000000,   9000000,  70000000,
#         24500000,   3450000,    850000,  10750000,    749999,  11000000,
#          5700000,  22000000,   2500000,  24000000,  32000000,   3550000,
#          2000000,   1000000,   2250000,   2690000,   5300000,   2675000,
#         17000000,  19350000,   4200000,  10500000,  13000000,  16000000,
#           255000,  19000000,   8860000,  18000000,   6250000,  27000000,
#         15500000,   3700000,   3400000,   5250000,   3300000,   4850000,
#          4114000,   1725000,   2575000,   3350000,   4350000,   3370000,
#          4700000,   4190000,   3190000,   6550000,   4950000,   2770000,
#         11010330,   6050000,   3650000,  12750000,   8540000,   7505000,
#          1770000,   5490000,  48500000,   3795000,   2100000,   2175000,
#          2800000,   4450000,   4100000,  12950000,   4349000,   2050000,
#          6150000,   4050000,   5350000,   5600000,   3275000,   7450000,
#          6200000,   6950000,   4390000,   2650000,   6700000,   8950000,
#          5195000,  11500000,   6600000,   6100000,  16950000,   6650000,
#          8100000,   2695000,  22699000,   5450000,   5650000,   7350000,
#          6850000,   5950000,  14750000,   7150000,   9995000,   8350000,
#          5900000,   9250000,  10200000,  13200000,   3200000,   4650000,
#          4550000,   3900000,  13950000,   3895000,   9800000,   2580000,
#          2850000,  34000000, 105000000,  33000000,  16250000,   7295000,
#         19750000,  17950000,   8900000,  22900000,   9975000,   5980000,
#         59900000,  17850000,  26550000,  18400000,  10800000,  14300000,
#          9650000,  13500000,  63500000,  12100000,   9200000,  56200000,
#        190000000,  95000000,   8800000,   6295000,  15750000,   7550000,
#         21000000,  12550000,  11124000,  21950000,  16750000,  67000000,
#         11250000,  17550000, 250000000,  26450000,  19900000,   9400000,
#         13800000,   5400000,   9550000,  20750000,  11450000,  13750000,
#         11900000,  14950000,  11550000,   7850000,   7750000,   5850000,
#         22700000,  21424500,  60000000,  10250000,  24750000,  15200000,
#          7900000,   8750000,  22240000,  29900000,  22250000,   7600000,
#         16500000,  28750000,   4895000,  21500000,  15950000,  18650000,
#         13900000,   6297500,   7650000,  18600000,  11200000,  17250000,
#         80000000,  52500000,  14850000,   8450000,   7950000,  22635450,
#         12800000,  10600000,  12250000,   8700000,  43250000, 430000000,
#        370000000,   7595000,   9850000,  10950000,   9950000,   6995000,
#          5175000,  19500000,   7395000,   4400000,   9450000,   7400000,
#          8275000,   3375000,   8495000,   4395000,   3950000,   5275000,
#          7100000,  10850000,   6350000,   7700000,   9900000,   6575000,
#         39050000,   4925000,   8300000,  22850000,   6900000,  38000000,
#          3525000,   5990000,   2895000, 121750000,   4490000,   3180000,
#          2975000,   4020000,   4975000,   3490000,    995000,   1600000,
#           175000,   3365000,   3890000,   4825000,   3980000,   6300000,
#          4080000,   8990000,   2625000,   3930000,   2980000,   8200000,
#           128000,  15800000,   5249000,   6675000,  81500000,   5680000,
#          6495000,  13700000,   7800000,   5575000,   5375000,   5150000,
#          8595000,   6875000,   6795000,   7495000,   7695000,   1200000,
#          2900000,   4625000,   4160000,  14250000,  17750000,   4600000,
#          5295000,   6145000,   3495000,  10300000,  15900000,  52000000,
#          5695000,   8250000,   3690000,   9495000,   7960000,   7275000,
#          6895000,  11700000,  19250000,   6975000,   5050000,   7690000,
#          7895000,   4270000,  10785000,   8295000,   5975000,   2920000,
#          9135000, 145000000,  50000000, 175000000,  37500000, 125000000,
#         29500000,  14350000,  19800000,   9875000,   4900000,   5100000,
#          5495000,   8575000,  13250000,  12700000,  15250000,  65000000,
#        200000000,  17100000,  51500000,  10925000,  19950000,  41000000,
#         17300000,   9725000,  12850000,   1835000, 615000000,   9300000,
#          3745000,  18250000,  12990000, 275000000,   5880000,   4980000,
#         73589000,  11790000,   3575000,  36000000,   5550000,   3590000,
#          3995000,   1400000,   7995000,   9100000,   4985000,   6280000,
#          2295000,  17650000,   4475000,   5280000,   4130000,   4495000,
#          2960000,  16900000,  18900000,   2965000,   4580000,   2450000,
#          2300000,   1950000,   9000600,   4990000,   2400000,   1830000,
#          1650000,    870000,   2618000,   2550000,   1290000,   1850000,
#          2350000,  10475000,   9895000,  12690000,   8850000])

# %%
#Checking location column

df.location.unique()
# Out:
# array(['Caferağa', 'Osmanağa', 'Rasimpaşa', 'Koşuyolu', 'Dumlupınar',
#        'Fikirtepe', 'Eğitim', 'Feneryolu', 'Zühtüpaşa', 'Fenerbahçe',
#        'Caddebostan', 'Göztepe', 'Merdivenköy', 'Sahrayı', '19',
#        'Erenköy', 'Suadiye', 'Kozyatağı', 'Bostancı', 'Acıbadem',
#        'Hasanpaşa'], dtype=object)

# %%
#Adjusting the location column

df.location.replace('19','19 Mayıs',inplace=True)
df.location.unique()
# Out:
# array(['Caferağa', 'Osmanağa', 'Rasimpaşa', 'Koşuyolu', 'Dumlupınar',
#        'Fikirtepe', 'Eğitim', 'Feneryolu', 'Zühtüpaşa', 'Fenerbahçe',
#        'Caddebostan', 'Göztepe', 'Merdivenköy', 'Sahrayı', '19 Mayıs',
#        'Erenköy', 'Suadiye', 'Kozyatağı', 'Bostancı', 'Acıbadem',
#        'Hasanpaşa'], dtype=object)

# %%
#Checking the netm2 column

df.netm2.unique()
# Out:
# array([55.0, 60.0, 85.0, 255.0, 100.0, 110.0, None, 200.0, 50.0, 90.0,
#        13.0, 160.0, 70.0, 638.0, 51.0, 170.0, 107.0, 26.0, 77.0, 213.0,
#        43.0, 68.0, 187.0, 340.0, 765.0, 120.0, 75.0, 467.0, 136.0, 272.0,
#        153.0, 31.0, 94.0, 102.0, 22.0, 124.0, 115.0, 56.0, 78.0, 140.0,
#        680.0, 150.0, 25.0, 119.0, 238.0, 66.0, 53.0, 24.0, 65.0, 425.0,
#        76.0, 17.0, 16.0, 111.0, 141.0, 128.0, 161.0, 64.0, 34.0, 1160.0,
#        500.0, 80.0, 935.0, 130.0, 204.0, 640.0, 240.0, 540.0, 190.0,
#        210.0, 420.0, 350.0, 260.0, 400.0, 144.0, 122.0, 155.0, 45.0,
#        256.0, 88.0, 40.0, 62.0, 92.0, 137.0, 67.0, 96.0, 47.0, 38.0, 98.0,
#        58.0, 101.0, 87.0, 192.0, 28.0, 30.0, 135.0, 173.0, 125.0, 145.0,
#        383.0, 95.0, 175.0, 86.0, 117.0, 105.0, 93.0, 148.0, 205.0, 114.0,
#        54.0, 185.0, 73.0, 3.0, 280.0, 1143.0, 168.0, 237.0, 220.0, 180.0,
#        138.0, 74.0, 310.0, 720.0, 357.0, 281.0, 121.0, 277.0, 72.0, 197.0,
#        142.0, 230.0, 133.0, 330.0, 195.0, 149.0, 103.0, 106.0, 147.0,
#        108.0, 178.0, 434.0, 375.0, 292.0, 250.0, 290.0, 251.0, 165.0,
#        79.0, 298.0, 468.0, 201.0, 112.0, 300.0, 253.0, 408.0, 221.0, 9.0,
#        104.0, 118.0, 320.0, 152.0, 123.0, 97.0, 39.0, 42.0, 132.0, 89.0,
#        82.0, 245.0, 3051.0, 83.0, 216.0, 29.0, 162.0, 57.0, 158.0, 12.0,
#        225.0, 302.0, 20.0, 176.0, 382.0, 510.0, 186.0, 270.0, 41.0, 84.0,
#        234.0, 81.0, 151.0, 19.0, 196.0, 189.0, 127.0, 61.0, 304.0, 268.0,
#        172.0, 850.0, 211.0, 143.0], dtype=object)

# %%
#Fillng the null values of the netm2 column statistically

mean_std_filling(df['netm2'])
df.info()
# Out:
# Mean: 129.152 Std: 110.404 Null: 132
# Numbers: [102.55698265  92.10251579  40.00845774 110.17299527 224.10288882
#  136.43468291 231.54718173 218.58819152 189.53824058 190.94580842]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   object
#  5   bedroom_number         1679 non-null   object
#  6   building_floor_number  1713 non-null   object
#  7   floor                  1647 non-null   object
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
# dtypes: int64(2), object(13)
# memory usage: 216.2+ KB
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_56488/2609805245.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_name[pd.isnull(column_name)] = rand_float

# %%
#Converting the column type to float
df = df.astype({"netm2": float})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1679 non-null   object
#  6   building_floor_number  1713 non-null   object
#  7   floor                  1647 non-null   object
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 216.2+ KB

# %%
#Checking the bedroom_number column

df.bedroom_number.unique()
# Out:
# array([21.0, 1.0, 2.0, 3.0, 31.0, 41.0, 11.0, None, 4.0, 22.0, 10.0, 6.0,
#        5.0, 42.0, 61.0, 71.0, 32.0, 51.0, 52.0, 73.0, 44.0, 62.0, 72.0],
#       dtype=object)

# %%
#Adjusting the bedroom_number column

df.bedroom_number.replace([21.,31.,41.,11.,22.,10.,42.,61.,71.,32.,51.,52.,73.,44.,62.,72.],
                         [2.,3.,4.,1.,2.,1.,4.,6.,7.,3.,5.,5.,7.,4.,6.,7.], inplace = True)

df.replace(np.nan,None,inplace=True)

df.bedroom_number.unique()
# Out:
# array([2.0, 1.0, 3.0, 4.0, None, 6.0, 5.0, 7.0], dtype=object)

# %%
#Fillng the null values of the bedroom_number column statistically
mean_std_filling(df['bedroom_number'])
df.info()
# Out:
# Mean: 2.825 Std: 1.004 Null: 165
# Numbers: [2.07608318 3.80989313 3.40972637 2.02247673 2.72228959 3.82191815
#  3.26156386 3.72061454 2.41720169 2.25174613]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   object
#  6   building_floor_number  1713 non-null   object
#  7   floor                  1647 non-null   object
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 216.2+ KB
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_56488/2609805245.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_name[pd.isnull(column_name)] = rand_float

# %%
#Converting the column type to float
df = df.astype({"bedroom_number": float})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   float64
#  6   building_floor_number  1713 non-null   object
#  7   floor                  1647 non-null   object
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 216.2+ KB

# %%
#Checking the building_floor_number column

df.building_floor_number.unique()
# Out:
# array([6.0, 4.0, 5.0, 8.0, 3.0, 7.0, None, 1.0, 1020.0, 2.0, 20.0, 9.0,
#        10.0], dtype=object)

# %%
#Adjusting the building_floor_number column

df.building_floor_number.replace(1020.,15,inplace=True)
df.replace(np.nan,None,inplace=True)
df.building_floor_number.unique()
# Out:
# array([6.0, 4.0, 5.0, 8.0, 3.0, 7.0, None, 1.0, 15.0, 2.0, 20.0, 9.0,
#        10.0], dtype=object)

# %%
#Fillng the null values of the building_floor_number column statistically
mean_std_filling(df['building_floor_number'])
df.info()
# Out:
# Mean: 8.894 Std: 4.642 Null: 131
# Numbers: [10.61864723  5.7487569  11.50005798 11.20911276 11.33172464 12.55610131
#   7.32676077  4.40599098  5.06126901  9.60225558]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   float64
#  6   building_floor_number  1844 non-null   object
#  7   floor                  1647 non-null   object
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 216.2+ KB
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_56488/2609805245.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_name[pd.isnull(column_name)] = rand_float

# %%
#Converting the column type to float
df = df.astype({"building_floor_number": float})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   float64
#  6   building_floor_number  1844 non-null   float64
#  7   floor                  1647 non-null   object
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 216.2+ KB

# %%
#Checking the floor column

df.floor.unique()
# Out:
# array(['6', 'Zemin Kat', 'Yüksek Giriş', '4', '3', '1', 'Bahçe katı',
#        'Bodrum Kat', None, '2', 'Giriş Katı', 'Kot 1', '5',
#        'Garden Floor', 'Kot 3', 'Çatı Katı', 'Müstakil', 'Komple', '12',
#        '7', '13', '20 ve üzeri', '11', '14', '10', '19', '18', '17', '16',
#        '8', '9', '15', 'Kot 2', 'Kot 4'], dtype=object)

# %%
#Adjusting the floor column

df.floor.replace(['Zemin Kat','Yüksek Giriş','Bahçe katı','Bodrum Kat','Giriş Katı','Kot 1','Garden Floor','Kot 3','20 ve üzeri','Kot 2','Kot 4'],
                [0,0,0,-1,0,1,0,3,25,2,4], inplace = True)

conditions = [
    (df['floor'] == 'Müstakil'),
    (df['floor'] == 'Komple')]
values = [1, 1]
df['private_house'] = np.select(conditions, values)

df.floor.replace(['Komple','Müstakil','6','4','3','1','2','5','12','7',
                  '13','11','14','10','19','18','17','16','8','9','15'],
                [None,None,6,4,3,1,2,5,12,7,13,11,14,10,19,18,17,16,8,9,15], inplace = True)

df['floor'] = df.apply(lambda x: x['building_floor_number'] if x['floor'] == 'Çatı Katı' else x['floor'], axis=1)

df.floor.unique()
# Out:
# array([ 6.,  0.,  4.,  3.,  1., -1., nan,  2.,  5., 12.,  7., 13., 25.,
#        11., 14., 10., 19., 18., 17., 16.,  8.,  9., 15.])

# %%
#Fillng the null values of the floor column statistically

mean_std_filling(df['floor'])
df.info()
# Out:
# Mean: 4.252 Std: 4.259 Null: 207
# Numbers: [2.83842533 3.01561039 6.30609243 7.54156513 6.44754606 5.8540319
#  1.90842601 7.35733746 3.90278303 8.25160192]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   float64
#  6   building_floor_number  1844 non-null   float64
#  7   floor                  1844 non-null   float64
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
#  15  private_house          1844 non-null   int64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 230.6+ KB
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_56488/2609805245.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_name[pd.isnull(column_name)] = rand_float

# %%
#Converting the column type to float
df = df.astype({"floor": float})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   float64
#  6   building_floor_number  1844 non-null   float64
#  7   floor                  1844 non-null   float64
#  8   heating_system         1747 non-null   object
#  9   age                    1736 non-null   object
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   object
#  15  private_house          1844 non-null   int64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 230.6+ KB

# %%
#Checkig the heating_system column

df.heating_system.unique()
# Out:
# array(['Kalorifer (Doğalgaz)', 'Klima', 'Merkezi Sistem',
#        'Kombi (Doğalgaz)', None, 'Merkezi Sistem (Isı Payı Ölçer)',
#        'Kombi (Elektrikli)', 'Yok', 'Combi Boiler (Natural Gas)',
#        'Fancoil', 'Yerden Isıtma', 'Soba (Kömür)', 'Güneş Enerjisi',
#        'Air Conditioner', 'None'], dtype=object)

# %%
#Adjusting the heating_system column

df.heating_system.replace('Kalorifer (Doğalgaz)','Natural Gas',inplace=True)
df.heating_system.replace('Klima','Air Conditioner',inplace=True)
df.heating_system.replace('Merkezi Sistem','Central System',inplace=True)
df.heating_system.replace('Kombi (Doğalgaz)','Natural Gas',inplace=True)
df.heating_system.replace('Merkezi Sistem (Isı Payı Ölçer)','Central System',inplace=True)
df.heating_system.replace('Kombi (Elektrikli)','Electric',inplace=True)
df.heating_system.replace('Combi Boiler (Natural Gas)','Natural Gas',inplace=True)
df.heating_system.replace('Yerden Isıtma','Underfloor Heating',inplace=True)
df.heating_system.replace('Soba (Kömür)','Stove',inplace=True)
df.heating_system.replace('Güneş Enerjisi','Solar Energy',inplace=True)
df.heating_system.replace('None',None,inplace=True)
df.heating_system.replace('Yok',None,inplace=True)
df.heating_system.unique()
# Out:
# array(['Natural Gas', 'Air Conditioner', 'Central System', None,
#        'Electric', 'Fancoil', 'Underfloor Heating', 'Stove',
#        'Solar Energy'], dtype=object)

# %%
#Checking the age column

df.age.unique()
# Out:
# array(['36-40', '16-20', '11-15', '6-10', '31-35', '21-25', '26-30', '2',
#        '40', '4', None, '0', '1', 'Between', '3', '5'], dtype=object)

# %%
#Adjusting the age column

df['age'] = df.apply(lambda x: '31-35' if x['Unnamed: 0'] == 106 else x['age'], axis=1)
df['age'] = df.apply(lambda x: '36-40' if x['Unnamed: 0'] == 314 else x['age'], axis=1)
df.replace('0','0-5',inplace=True)
df.replace('1','0-5',inplace=True)
df.replace('2','0-5',inplace=True)
df.replace('3','0-5',inplace=True)
df.replace('4','0-5',inplace=True)
df.replace('5','0-5',inplace=True)
df.replace('40','36-40',inplace=True)

df.age.replace(['0-5','6-10','11-15','16-20','21-25','26-30','31-35','36-40','6-10'],
                         [8,7,6,5,4,3,2,1,0], inplace = True)

df.age.unique()
# Out:
# array([ 1.,  5.,  6.,  7.,  2.,  4.,  3.,  8., nan])

# %%
#Fillng the null values of the floor column statistically

mean_std_filling(df['age'])
df.info()
# Out:
# Mean: 5.467 Std: 2.508 Null: 108
# Numbers: [6.01901701 6.70384412 5.13095586 6.26586907 4.21822838 4.81870397
#  3.29828982 5.1347957  3.71424558 6.74242155]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   float64
#  6   building_floor_number  1844 non-null   float64
#  7   floor                  1844 non-null   float64
#  8   heating_system         1735 non-null   object
#  9   age                    1844 non-null   float64
#  10  situation              1655 non-null   object
#  11  seller                 870 non-null    object
#  12  title_dead_status      931 non-null    object
#  13  credit                 1826 non-null   object
#  14  rent_income            1308 non-null   float64
#  15  private_house          1844 non-null   int64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 230.6+ KB

# %%
#Checking the situation column
df.situation.unique()
# Out:
# array(['Boş', 'Kiracılı', 'Mülk', None, 'Occupied', 'Vacant'],
#       dtype=object)

# %%
#Adjusting the column
df.situation.replace('Boş','Vacant',inplace =True)
df.situation.replace('Kiracılı','Occupied',inplace =True)
df.situation.fillna('Vacant',inplace=True)
df.situation.replace('Mülk','Vacant',inplace =True)
df.situation.unique()
# Out:
# array(['Vacant', 'Occupied'], dtype=object)

# %%
#Checking the seller column
df.seller.unique()
# Out:
# array(['Danışman', None, 'İnşaat', 'Agent'], dtype=object)

# %%
#Adjusting the column

df.seller.replace('Danışman','Agent',inplace =True)
df.seller.replace('İnşaat','Construction',inplace =True)
df.seller.fillna('From Owner',inplace=True)
df.seller.unique()
# Out:
# array(['Agent', 'From Owner', 'Construction'], dtype=object)

# %%
#Checking the title_dead_status column
df.title_dead_status.unique()
# Out:
# array([None, 'Kat Mülkiyeti', 'Arsa Tapulu', 'Müstakil Parsel',
#        'Kat İrtifakı', 'Hisseli Tapu', 'Construction Servitude',
#        'İskanı Alınmış', 'Bilinmiyor'], dtype=object)

# %%
#Dropping the column due to the excess of unknown values
df.drop('title_dead_status', inplace=True, axis=1)

# %%
#Checing the credit column
df.credit.unique()
# Out:
# array(['Hayır', 'Evet', None, 'Yes'], dtype=object)

# %%
#Adjusting the credti column
df.credit.replace('Hayır',0,inplace =True)
df.credit.replace('Evet',1,inplace =True)
df.credit.replace('Yes',1,inplace =True)

df.credit.unique()
# Out:
# array([ 0.,  1., nan])

# %%
#Fillng the null values of the floor column statistically

mean_std_filling(df['credit'])
df.info()
# Out:
# Mean: 0.927 Std: 0.26 Null: 18
# Numbers: [0.69814295 0.69501049 0.92290725 0.70731813 0.68898743 0.93449229
#  0.79025846 0.83691927 0.78556256 0.8573238 ]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   float64
#  6   building_floor_number  1844 non-null   float64
#  7   floor                  1844 non-null   float64
#  8   heating_system         1735 non-null   object
#  9   age                    1844 non-null   float64
#  10  situation              1844 non-null   object
#  11  seller                 1844 non-null   object
#  12  credit                 1844 non-null   float64
#  13  rent_income            1308 non-null   float64
#  14  private_house          1844 non-null   int64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 216.2+ KB

# %%
#Checking the rent_income column
df.rent_income.unique()
# Out:
# array([3.00e+04,      nan, 0.00e+00, 2.00e+04, 8.00e+03, 1.30e+04,
#        1.50e+04, 1.00e+04, 3.50e+03, 1.20e+04, 3.30e+04, 2.10e+04,
#        4.90e+03, 5.50e+03, 1.40e+04, 7.50e+03, 9.50e+03, 8.50e+03,
#        1.00e+00, 2.50e+04, 1.70e+04, 6.00e+03, 1.80e+04, 4.00e+04,
#        6.00e+04, 4.50e+04, 5.00e+04, 2.20e+04, 6.50e+03, 1.25e+04,
#        7.20e+04, 7.00e+03, 9.00e+03, 4.50e+03, 3.50e+04, 1.60e+04,
#        2.30e+04, 2.75e+04, 3.00e+03, 5.00e+01, 2.50e+02])

# %%
#Dropping the column due to the excess of 0 values
df.drop('rent_income', inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1844 non-null   int64
#  1   listing_names          1844 non-null   object
#  2   listing_prices         1844 non-null   int64
#  3   location               1844 non-null   object
#  4   netm2                  1844 non-null   float64
#  5   bedroom_number         1844 non-null   float64
#  6   building_floor_number  1844 non-null   float64
#  7   floor                  1844 non-null   float64
#  8   heating_system         1735 non-null   object
#  9   age                    1844 non-null   float64
#  10  situation              1844 non-null   object
#  11  seller                 1844 non-null   object
#  12  credit                 1844 non-null   float64
#  13  private_house          1844 non-null   int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 201.8+ KB

# %%
#Drop the null values
df.dropna(inplace=True)

#Drop the unnecessary columns
df.drop('Unnamed: 0', inplace=True, axis=1)
df.drop('listing_names', inplace=True, axis=1)
df.drop_duplicates(inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1686 entries, 0 to 1843
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   listing_prices         1686 non-null   int64
#  1   location               1686 non-null   object
#  2   netm2                  1686 non-null   float64
#  3   bedroom_number         1686 non-null   float64
#  4   building_floor_number  1686 non-null   float64
#  5   floor                  1686 non-null   float64
#  6   heating_system         1686 non-null   object
#  7   age                    1686 non-null   float64
#  8   situation              1686 non-null   object
#  9   seller                 1686 non-null   object
#  10  credit                 1686 non-null   float64
#  11  private_house          1686 non-null   int64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 171.2+ KB

# %%
# Let's say we want to split the data in 80:10:10 for train:valid:test dataset
train_size=0.8

x = df.drop(columns = ['listing_prices','location','heating_system','situation','seller']).copy()
y = df['listing_prices']

# In the first step we will split the data in training and remaining dataset
x_train, x_rem, y_train, y_rem = train_test_split(x,y, train_size=0.8)

# Now since we want the valid and test size to be equal (10% each of overall data). 
# we have to define valid_size=0.5 (that is 50% of remaining data)
test_size = 0.5
x_cv, x_test, y_cv, y_test = train_test_split(x_rem,y_rem, test_size=0.5)

print(x_train.shape), print(y_train.shape)
print(x_cv.shape), print(y_cv.shape)
print(x_test.shape), print(y_test.shape)
# Out:
# (1348, 7)
# (1348,)
# (169, 7)
# (169,)
# (169, 7)
# (169,)
# (None, None)

# %%
# Building model
lreg = LinearRegression()

lreg.fit(x_train,y_train)

pred = lreg.predict(x_cv)

# MSE Calculation
mse = np.mean((pred - y_cv)**2)
print("MSE: ", mse)

# R2 Skor
print("R2 Score: ", lreg.score(x_cv, y_cv))
# Out:
# MSE:  233494902820444.84
# R2 Score:  0.1373294281259544

# %%
#Analyze the listing prices column
plt.figure(figsize=[18,5])

plt.suptitle('Listing Sales Prices', fontsize = 16)

plt.subplot(1,2,1)
sns.histplot(data = df['listing_prices'], kde=True)
plt.title('df')
# Out:
# Text(0.5, 1.0, 'df')

# %%
plt.figure(figsize=[18,5])
sns.boxplot(x=df['listing_prices'], data=df);

# %%
def extract_whiskers(data, whisker=1.5):
    median_value = np.median(data) # Median
    upper_quartile = np.percentile(data, 75) # 75%
    lower_quartile = np.percentile(data, 25) # 25% 

    iqr = upper_quartile - lower_quartile # Interquartile Range
    
    upper_whisker = data[data<=upper_quartile+whisker*iqr].max() # Max accepted value
    lower_whisker = data[data>=lower_quartile-whisker*iqr].min() # Min accepted value
    
    print("Upper Whisker:", upper_whisker)
    print("Lower Whisker:", lower_whisker)

# %%
extract_whiskers(df['listing_prices'])
# Out:
# Upper Whisker: 23500000
# Lower Whisker: 128000

# %%
df = df.loc[df['listing_prices'] <= 23500000]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1552 entries, 0 to 1843
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   listing_prices         1552 non-null   int64
#  1   location               1552 non-null   object
#  2   netm2                  1552 non-null   float64
#  3   bedroom_number         1552 non-null   float64
#  4   building_floor_number  1552 non-null   float64
#  5   floor                  1552 non-null   float64
#  6   heating_system         1552 non-null   object
#  7   age                    1552 non-null   float64
#  8   situation              1552 non-null   object
#  9   seller                 1552 non-null   object
#  10  credit                 1552 non-null   float64
#  11  private_house          1552 non-null   int64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 157.6+ KB

# %%
plt.figure(figsize=[18,5])

plt.suptitle('Listing Sales Prices', fontsize = 16)

plt.subplot(1,2,1)
sns.histplot(data = df['listing_prices'], kde=True)
plt.title('df')
# Out:
# Text(0.5, 1.0, 'df')

# %%
df['listing_prices'] = np.log(df['listing_prices'])
sns.histplot(data = df['listing_prices'], kde=True);

# %%
#Analyze the Net M2 column
plt.figure(figsize=[18,5])

plt.suptitle('Net M2', fontsize = 16)

plt.subplot(1,2,1)
sns.histplot(data = df['netm2'], kde=True)
plt.title('df')
# Out:
# Text(0.5, 1.0, 'df')

# %%
plt.figure(figsize=[18,5])
sns.boxplot(x=df['netm2'], data=df);

# %%
extract_whiskers(df['netm2'])
# Out:
# Upper Whisker: 222.09040541471245
# Lower Whisker: 3.0

# %%
df = df.loc[df['netm2'] <= 222.09040541471245]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1487 entries, 0 to 1843
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   listing_prices         1487 non-null   float64
#  1   location               1487 non-null   object
#  2   netm2                  1487 non-null   float64
#  3   bedroom_number         1487 non-null   float64
#  4   building_floor_number  1487 non-null   float64
#  5   floor                  1487 non-null   float64
#  6   heating_system         1487 non-null   object
#  7   age                    1487 non-null   float64
#  8   situation              1487 non-null   object
#  9   seller                 1487 non-null   object
#  10  credit                 1487 non-null   float64
#  11  private_house          1487 non-null   int64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 151.0+ KB

# %%
plt.figure(figsize=[18,5])

plt.suptitle('Net M2', fontsize = 16)

plt.subplot(1,2,1)
sns.histplot(data = df['netm2'], kde=True)
plt.title('df')
# Out:
# Text(0.5, 1.0, 'df')

# %%
sns.pairplot(df);

# %%
#df['netm2'] = np.log(df['netm2'])
#sns.pairplot(df);

# %%
df.location.value_counts()
# Out:
# Suadiye        235
# Göztepe        180
# Erenköy        156
# Fenerbahçe     136
# Caddebostan    127
# Feneryolu      108
# Bostancı       104
# Osmanağa        56
# Kozyatağı       55
# 19 Mayıs        48
# Caferağa        45
# Merdivenköy     33
# Acıbadem        33
# Fikirtepe       30
# Sahrayı         29
# Hasanpaşa       24
# Zühtüpaşa       23
# Eğitim          17
# Koşuyolu        17
# Dumlupınar      16
# Rasimpaşa       15
# Name: location, dtype: int64

# %%
df.heating_system.value_counts()
# Out:
# Natural Gas           649
# Central System        531
# Air Conditioner       273
# Underfloor Heating     27
# Electric                3
# Fancoil                 2
# Stove                   1
# Solar Energy            1
# Name: heating_system, dtype: int64

# %%
df.heating_system.replace('Underfloor Heating','Others',inplace=True)
df.heating_system.replace('Electric','Others',inplace=True)
df.heating_system.replace('Fancoil','Others',inplace=True)
df.heating_system.replace('Stove','Others',inplace=True)
df.heating_system.replace('Solar Energy','Others',inplace=True)
df.heating_system.value_counts()
# Out:
# Natural Gas        649
# Central System     531
# Air Conditioner    273
# Others              34
# Name: heating_system, dtype: int64

# %%
df.situation.value_counts()
# Out:
# Vacant      956
# Occupied    531
# Name: situation, dtype: int64

# %%
df.seller.value_counts()
# Out:
# From Owner      793
# Agent           689
# Construction      5
# Name: seller, dtype: int64

# %%
df = pd.get_dummies(df, columns=['location', 'heating_system', 'situation',
                                      'seller'], drop_first=True)

# %%
plt.figure(figsize=[18,12])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1, fmt='.1f');

# %%
# Let's say we want to split the data in 80:10:10 for train:valid:test dataset
train_size=0.8

x = df.drop(columns = ['listing_prices']).copy()
y = df['listing_prices']

# In the first step we will split the data in training and remaining dataset
x_train, x_rem, y_train, y_rem = train_test_split(x,y, train_size=0.8)

# Now since we want the valid and test size to be equal (10% each of overall data). 
# we have to define valid_size=0.5 (that is 50% of remaining data)
test_size = 0.5
x_cv, x_test, y_cv, y_test = train_test_split(x_rem,y_rem, test_size=0.5)

print(x_train.shape), print(y_train.shape)
print(x_cv.shape), print(y_cv.shape)
print(x_test.shape), print(y_test.shape)
# Out:
# (1189, 33)
# (1189,)
# (149, 33)
# (149,)
# (149, 33)
# (149,)
# (None, None)

# %%
lreg = LinearRegression()

lreg.fit(x_train,y_train)

pred = lreg.predict(x_train)

mse = np.mean((pred - y_train)**2)

# Hata Metrikleri
print("Train Score: ", lreg.score(x_train, y_train))
print("MSE: ", mse)
# Out:
# Train Score:  0.5650052468448425
# MSE:  0.13841274127493158

# %%
lreg = LinearRegression()

lreg.fit(x_train,y_train)

pred = lreg.predict(x_cv)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", lreg.score(x_cv, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  0.4781296505260234
# MSE:  0.27521578431422145

# %%
predictors = x_train.columns
coef = Series(lreg.coef_,predictors).sort_values(ascending=False)
plt.figure(figsize=[16,5])
coef.plot(kind='bar', title='Modal Coefficients');

# %%
from sklearn.preprocessing import MinMaxScaler

lreg2 = LinearRegression()

minmax_scale = MinMaxScaler()
x_train_mms = minmax_scale.fit_transform(x_train.values)
x_cv_mms = minmax_scale.fit_transform(x_cv.values)

lreg2.fit(x_train_mms,y_train)

pred = lreg2.predict(x_cv_mms)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", lreg2.score(x_cv_mms, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  0.48153448763880957
# MSE:  0.2734201948207732

# %%
predictors = x_train.columns
coef = Series(lreg2.coef_,predictors).sort_values(ascending=False)
plt.figure(figsize=[16,5])
coef.plot(kind='bar', title='Modal Coefficients');

# %%
from sklearn.linear_model import Ridge

ridgeReg = Ridge(alpha=1)

ridgeReg.fit(x_train_mms,y_train)

pred = ridgeReg.predict(x_cv_mms)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", ridgeReg.score(x_cv_mms, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  0.4794738804006329
# MSE:  0.27450688548597385

# %%
ridgeReg2 = Ridge(alpha=100)

ridgeReg2.fit(x_train_mms,y_train)

pred = ridgeReg2.predict(x_cv_mms)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", ridgeReg2.score(x_cv_mms, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  0.2934765580487181
# MSE:  0.3725952306142687

# %%
ridgeReg3 = Ridge(alpha=10000)

ridgeReg3.fit(x_train_mms,y_train)

pred = ridgeReg3.predict(x_cv_mms)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", ridgeReg3.score(x_cv_mms, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  0.004484317163727769
# MSE:  0.5249994174320392

# %%
from sklearn.metrics import r2_score

alphalist = 10**(np.linspace(0,2,200)) # Daha geniş aralıkta inceleme yapmak için np.linspace() parametrelerini değiştirin
err_vec_val = np.zeros(len(alphalist))
err_vec_train = np.zeros(len(alphalist))

for index, curr_alpha in enumerate(alphalist):

    ridge = Ridge(alpha = curr_alpha)
    ridge.fit(x_train_mms, y_train)

    val_set_pred = ridge.predict(x_cv_mms)
    err_vec_val[index] = r2_score(y_cv, val_set_pred)

# %%
plt.plot(alphalist, err_vec_val);

# %%
np.max(err_vec_val)
# Out:
# 0.4794738804006329

# %%
alphalist[np.argmax(err_vec_val)]
# Out:
# 1.0

# %%
ridgeReg4 = Ridge(alpha=1)

ridgeReg4.fit(x_train_mms,y_train)

pred = ridgeReg4.predict(x_cv_mms)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", ridgeReg4.score(x_cv_mms, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  0.4794738804006329
# MSE:  0.27450688548597385

# %%
from sklearn.linear_model import Lasso

lassoReg = Lasso(alpha=1)

lassoReg.fit(x_train_mms,y_train)

pred = lassoReg.predict(x_cv_mms)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", lassoReg.score(x_cv_mms, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  -0.0034019116513048786
# MSE:  0.52915833286151

# %%
lassoReg2 = Lasso(alpha=100)

lassoReg2.fit(x_train_mms,y_train)

pred = lassoReg2.predict(x_cv_mms)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", lassoReg2.score(x_cv_mms, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  -0.0034019116513048786
# MSE:  0.52915833286151

# %%
lassoReg3 = Lasso(alpha=10000)

lassoReg3.fit(x_train_mms,y_train)

pred = lassoReg3.predict(x_cv_mms)

mse = np.mean((pred - y_cv)**2)

print("Validation Score: ", lassoReg3.score(x_cv_mms, y_cv))
print("MSE: ", mse)
# Out:
# Validation Score:  -0.0034019116513048786
# MSE:  0.52915833286151

# %%
lreg3 = LinearRegression()

x_train_mms = minmax_scale.fit_transform(x_train.values)
x_test_mms = minmax_scale.fit_transform(x_test.values)

lreg3.fit(x_train_mms,y_train)

pred = lreg3.predict(x_test_mms)

mse = np.mean((pred - y_test)**2)

print("Test Score: ", lreg3.score(x_test_mms, y_test))
print("MSE: ", mse)
# Out:
# Test Score:  0.6841166209728246
# MSE:  0.10450883016807322

# %%
test_mms = minmax_scale.fit_transform(x_test.values)
lreg3.predict(test_mms)
# Out:
# array([15.55503393, 15.43986315, 15.53641985, 15.49810507, 16.10473035,
#        16.22710841, 15.69854888, 15.86242775, 16.12867042, 16.25424304,
#        15.95848182, 15.56663477, 15.80463949, 15.77285662, 15.59227177,
#        15.6400102 , 15.78552782, 15.94730444, 15.67983191, 15.76503645,
#        15.36958473, 15.448541  , 16.08919248, 15.68318597, 16.45441903,
#        15.91440737, 15.70540997, 15.69451328, 15.93238732, 16.00560248,
#        15.64901082, 15.70787445, 14.93287724, 15.49238023, 15.45666683,
#        15.69929439, 16.23590076, 15.53054012, 15.40499324, 15.4929177 ,
#        16.06403517, 16.3240723 , 15.59458044, 15.25527779, 15.84076797,
#        15.99448825, 16.46191246, 16.59446918, 16.14761283, 16.17249634,
#        15.69844391, 15.25721718, 15.75877999, 15.0648247 , 14.89270308,
#        15.26486609, 15.64849083, 15.71738449, 14.54154312, 15.6219348 ,
#        15.60326372, 16.6298915 , 15.44415445, 15.11137196, 16.00847615,
#        16.07322674, 16.44998269, 15.73623083, 15.24051259, 16.12590699,
#        14.42108967, 15.68826739, 15.91164128, 15.46091659, 15.92972632,
#        16.08863525, 16.39457776, 15.56699866, 15.89267199, 16.20183936,
#        15.95051325, 16.49885203, 14.87869404, 15.11115549, 16.07718884,
#        15.74336418, 16.13645599, 15.48299308, 14.97167249, 15.35304945,
#        16.19544518, 15.5988917 , 15.90220149, 16.21428478, 15.26010707,
#        15.58157754, 15.57428402, 15.65169838, 15.18193349, 15.37173411,
#        15.35301814, 15.30919508, 15.57934168, 15.87743694, 15.71102818,
#        15.88245855, 15.74541436, 15.76584635, 14.96359422, 16.05133118,
#        15.97503049, 16.3663345 , 15.66445056, 16.31236552, 16.72781867,
#        15.52177858, 15.71988226, 15.44933613, 16.67705117, 14.87298782,
#        16.18468313, 15.77593509, 16.20569105, 16.4969446 , 15.46343374,
#        15.50647222, 15.3729351 , 15.35780594, 16.55173329, 15.67900723,
#        15.27975256, 15.65177578, 15.73137529, 16.28906761, 16.42408195,
#        14.93116551, 15.61029733, 15.60472609, 16.43404675, 15.33816904,
#        16.04758499, 15.59720798, 15.42196392, 15.6617196 , 15.98145624,
#        15.25015285, 16.38433276, 15.25475363, 15.72356556])

# %%
np.exp(lreg3.predict(test_mms))
# Out:
# array([ 5694628.53506365,  5075132.28016939,  5589608.71454382,
#         5379495.04540007,  9867236.1360678 , 11151765.74151895,
#         6573446.78022481,  7743991.07008471, 10106308.74679745,
#        11458507.70627651,  8524729.23354182,  5761075.69254409,
#         7309164.20152073,  7080510.88722293,  5910681.93332992,
#         6199692.17800168,  7170800.2414467 ,  8429975.65311236,
#         6451556.06018993,  7025356.01491141,  4730704.67246443,
#         5119365.17260285,  9715105.32512571,  6473231.31511882,
#        13997916.15899589,  8157166.02388287,  6618702.91279473,
#         6546972.43048897,  8305157.9162823 ,  8936034.4706904 ,
#         6255745.12232454,  6635034.64400286,  3056794.09208158,
#         5348786.26711779,  5161133.71235683,  6578349.16694156,
#        11250248.35117673,  5556839.77144521,  4901212.80313706,
#         5351661.853011  ,  9473748.0679925 , 12287245.15565488,
#         5924343.50024531,  4219713.5081759 ,  7578061.39427896,
#         8837267.26627601, 14103202.46967011, 16102243.61347327,
#        10299571.3146084 , 10559076.12856667,  6572756.80109428,
#         4227905.08227842,  6981539.39815376,  3487949.90102711,
#         2936424.02407743,  4260367.98011736,  6252493.04803066,
#         6698435.06738008,  2066864.16567374,  6088636.99885649,
#         5976010.22818359, 16682844.91163726,  5096958.0242746 ,
#         3654142.29634028,  8961750.61667771,  9561228.08977023,
#        13935954.15945883,  6825873.1664952 ,  4157866.28016321,
#        10078419.22252515,  1832313.01642604,  6506208.22882707,
#         8134633.76768617,  5183113.99734545,  8283087.33077135,
#         9709693.27857389, 13184833.69431439,  5763172.50945452,
#         7981779.93846752, 10873501.78806067,  8457069.28165828,
#        14633910.42102278,  2895574.34580654,  3653351.36345605,
#         9599185.8003969 ,  6874738.60951875, 10185299.31129274,
#         5298811.34969842,  3177713.5730886 ,  4653124.34827923,
#        10804196.49765316,  5949940.06193435,  8058205.88245485,
#        11009672.66279695,  4240140.95095942,  5847808.51336421,
#         5805312.60246383,  6272580.42077109,  3921298.84027053,
#         4740883.70624454,  4652978.6299697 ,  4453474.2594147 ,
#         5834748.27962447,  7861098.68225519,  6655992.80544019,
#         7900673.34052744,  6888847.53467602,  7031048.16648081,
#         3152146.52832754,  9354154.91878076,  8666975.93267442,
#        12817660.39374214,  6353081.708297  , 12144239.79401442,
#        18399217.07759102,  5508365.9696721 ,  6715187.15540665,
#         5123437.34384435, 17488449.12108045,  2879098.60542647,
#        10688544.64172945,  7102341.58650017, 10915463.95343381,
#        14606023.89338786,  5196177.10045542,  5424694.92648939,
#         4746580.8862581 ,  4675309.57901142, 15428596.96966455,
#         6446237.75731455,  4324264.20834976,  6273065.92451429,
#         6792810.21259201, 11864574.76844656, 13579636.97606305,
#         3051566.13999756,  6018191.33642558,  5984755.7501297 ,
#        13715631.8790967 ,  4584396.5533316 ,  9319178.05325611,
#         5939930.41011134,  4985099.51909615,  6335755.38269247,
#         8722847.08830231,  4198143.04783958, 13050444.6082015 ,
#         4217502.27041683,  6739966.84775222])

# %%
x_test['Prediction'] = np.exp(lreg3.predict(test_mms))
x_test
# Out:
#       netm2  bedroom_number  building_floor_number  floor  age  credit  \
# 811    70.0        2.000000                   10.0    7.0  8.0     1.0
# 1731  130.0        3.000000                    3.0    3.0  4.0     1.0
# 1098  105.0        3.000000                   10.0    8.0  3.0     1.0
# 1809  125.0        3.000000                    9.0    7.0  3.0     1.0
# 445    90.0        2.000000                   15.0   10.0  8.0     1.0
# ...     ...             ...                    ...    ...  ...     ...
# 1284  145.0        2.000000                    4.0    0.0  3.0     1.0
# 1657  100.0        2.000000                    4.0    2.0  3.0     1.0
# 575   120.0        3.000000                    6.0    1.0  8.0     1.0
# 1627   90.0        3.673123                    6.0    1.0  2.0     1.0
# 922    85.0        2.000000                    7.0    3.0  8.0     1.0
#
#       private_house  location_Acıbadem  location_Bostancı  \
# 811               0                  0                  0
# 1731              0                  1                  0
# 1098              0                  0                  0
# 1809              0                  0                  1
# 445               0                  0                  0
# ...             ...                ...                ...
# 1284              0                  0                  0
# 1657              0                  0                  1
# 575               0                  0                  0
# 1627              0                  0                  1
# 922               0                  0                  0
#
#       location_Caddebostan  ...  location_Sahrayı  location_Suadiye  \
# 811                      0  ...                 0                 0
# 1731                     0  ...                 0                 0
# 1098                     0  ...                 0                 0
# 1809                     0  ...                 0                 0
# 445                      0  ...                 0                 0
# ...                    ...  ...               ...               ...
# 1284                     0  ...                 0                 1
# 1657                     0  ...                 0                 0
# 575                      0  ...                 0                 0
# 1627                     0  ...                 0                 0
# 922                      0  ...                 0                 0
#
#       location_Zühtüpaşa  heating_system_Central System  \
# 811                    0                              0
# 1731                   0                              0
# 1098                   0                              1
# 1809                   0                              0
# 445                    0                              0
# ...                  ...                            ...
# 1284                   0                              1
# 1657                   0                              1
# 575                    0                              0
# 1627                   0                              0
# 922                    0                              0
#
#       heating_system_Natural Gas  heating_system_Others  situation_Vacant  \
# 811                            1                      0                 1
# 1731                           1                      0                 0
# 1098                           0                      0                 0
# 1809                           1                      0                 1
# 445                            0                      1                 1
# ...                          ...                    ...               ...
# 1284                           0                      0                 0
# 1657                           0                      0                 1
# 575                            0                      0                 1
# 1627                           1                      0                 1
# 922                            0                      0                 1
#
#       seller_Construction  seller_From Owner    Prediction
# 811                     0                  0  5.694629e+06
# 1731                    0                  1  5.075132e+06
# 1098                    0                  0  5.589609e+06
# 1809                    0                  0  5.379495e+06
# 445                     0                  1  9.867236e+06
# ...                   ...                ...           ...
# 1284                    0                  0  8.722847e+06
# 1657                    0                  1  4.198143e+06
# 575                     0                  1  1.305044e+07
# 1627                    0                  1  4.217502e+06
# 922                     0                  1  6.739967e+06
#
# [149 rows x 34 columns]
